# %% [markdown]
# ### 결측치 제거

# %%
data = {
    '이름' : ['김자바', '이자바', '박자바', '최캐드', '정캐드'],
    '학급' : ['자바반', '자바반', '자바반', '캐드반', '캐드반'],
    '국어점수' : [90, 80, 70, 100, 90],
    '영어점수' : [70, 80, 80, 70, 90],
    '평균' : [90.0, 80.0, 75.0, 85.0, 90.0],
    '취미' : ['독서', '', '', '요가', '축구']
}

# %%
import pandas as pd
df = pd.DataFrame(data)
df
# Out:
#     이름   학급  국어점수  영어점수    평균  취미
# 0  김자바  자바반    90    70  90.0  독서
# 1  이자바  자바반    80    80  80.0
# 2  박자바  자바반    70    80  75.0
# 3  최캐드  캐드반   100    70  85.0  요가
# 4  정캐드  캐드반    90    90  90.0  축구

# %%
df.to_excel('student2.xlsx')

# %%
df = pd.read_excel('student.xlsx')
df
# Out:
#    Unnamed: 0   이름   학급  국어점수  영어점수  평균   취미
# 0           0  김자바  자바반    90    70  90   독서
# 1           1  이자바  자바반    80    80  80  NaN
# 2           2  박자바  자바반    70    80  75  NaN
# 3           3  최캐드  캐드반   100    70  85   요가
# 4           4  정캐드  캐드반    90    90  90   축구

# %%
# 만약 엑셀 파일로 만들 때 index가 중요하다면 아래처럼
# 인덱스 생성 후 인덱스를 제외하지 않고 엑셀 파일로 생성
df.index = ['1번', '2번', '3번', '4번', '5번']
df.index.name = '학번'
df
# Out:
#      이름   학급  국어점수  영어점수    평균  취미
# 학번
# 1번  김자바  자바반    90    70  90.0  독서
# 2번  이자바  자바반    80    80  80.0
# 3번  박자바  자바반    70    80  75.0
# 4번  최캐드  캐드반   100    70  85.0  요가
# 5번  정캐드  캐드반    90    90  90.0  축구

# %%
# 엑셀 파일로 내보낼 때 인덱스가 큰 의미가 없다면
# 엑셀 파일로 변환 시 인덱스는 제외하고 엑셀 파일 생성
df.to_excel('student2.xlsx', index=False)
df
# Out:
#      이름   학급  국어점수  영어점수    평균  취미
# 학번
# 1번  김자바  자바반    90    70  90.0  독서
# 2번  이자바  자바반    80    80  80.0
# 3번  박자바  자바반    70    80  75.0
# 4번  최캐드  캐드반   100    70  85.0  요가
# 5번  정캐드  캐드반    90    90  90.0  축구

# %%
# 인덱스를 제외하고 만든 엑셀 파일 
df = pd.read_excel('student2.xlsx')
df

# %%
# 임의로 생성한 인덱스를 가진 엑셀 파일 로딩하기
df = pd.read_excel('student1.xlsx', index_col='학번')
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 2
#       1 # 임의로 생성한 인덱스를 가진 엑셀 파일 로딩하기
# ----> 2 df = pd.read_excel('student1.xlsx', index_col='학번')
#       3 df
#
# File c:\Users\GRS\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:508, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#     507 try:
# --> 508     data = io.parse(
#     509         sheet_name=sheet_name,
# ...

# %%
# 특정 컬럼의 NaN 값을 변경하는 방법
# inplace = True를 주지 않으면 변경내용이 저장되지 않는다
df['취미'].fillna('없음', inplace=True)
df
# Out:
#      이름   학급  국어점수  영어점수    평균  취미
# 학번
# 1번  김자바  자바반    90    70  90.0  독서
# 2번  이자바  자바반    80    80  80.0
# 3번  박자바  자바반    70    80  75.0
# 4번  최캐드  캐드반   100    70  85.0  요가
# 5번  정캐드  캐드반    90    90  90.0  축구

# %%
# NaN 값을 제거할 때는 dropna() 함수 호출
# dropna 함수는 axis, how 라는 두 가지 매개변수를 가짐
# 사용예시 : df.dropna(axis=?, how=?)
# axis = 'index' : NaN의 데이터를 기준으로 행을 삭제 (default)
# axis = 'columns' : NaN 데이터를 기준으로 열을 삭제
# how = 'any' : NaN 값이 하나라도 있으면 데이터 삭제 (default)
# how = 'all' : 모든 값이 NaN이면 데이터 삭제
# inplace = True 매개변수를 주면 변경내용이 저장

# %%
# df.dropna()
# df.dropna(how='all')
df.dropna(axis='columns', how='any')
# Out:
#      이름   학급  국어점수  영어점수    평균  취미
# 학번
# 1번  김자바  자바반    90    70  90.0  독서
# 2번  이자바  자바반    80    80  80.0
# 3번  박자바  자바반    70    80  75.0
# 4번  최캐드  캐드반   100    70  85.0  요가
# 5번  정캐드  캐드반    90    90  90.0  축구

# %%
# 특정 컬럼의 값을 NaN으로 바꾸기
# numpy : 수학과 관련된 여러기능을 제공하는 라이브러리
import numpy as np
df['학급'] = np.nan
df
# Out:
#      이름  학급  국어점수  영어점수    평균  취미
# 학번
# 1번  김자바 NaN    90    70  90.0  독서
# 2번  이자바 NaN    80    80  80.0
# 3번  박자바 NaN    70    80  75.0
# 4번  최캐드 NaN   100    70  85.0  요가
# 5번  정캐드 NaN    90    90  90.0  축구

# %%
df.dropna(axis='columns', how='all')
# Out:
#      이름  국어점수  영어점수    평균  취미
# 학번
# 1번  김자바    90    70  90.0  독서
# 2번  이자바    80    80  80.0
# 3번  박자바    70    80  75.0
# 4번  최캐드   100    70  85.0  요가
# 5번  정캐드    90    90  90.0  축구
