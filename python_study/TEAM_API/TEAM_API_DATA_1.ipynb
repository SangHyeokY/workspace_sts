# %%
# Python3 샘플 코드 
# 1)

import requests

url = 'http://apis.data.go.kr/3210000/SeochoIaqSvc/getSeochoIaqRtData'
params ={'serviceKey' : 'qGP0J9zjn24+7F0ShvS2CqxEKttV9xuw+qyl5TnY6Pnhfe/Z0isTfz84U7GKB1HU3jvTDb7XrQKo0ROo23TNSw==', 'numOfRows' : '90', 'pageNo' : '1' }

response = requests.get(url, params=params)
print(response.content)
# Out:
# b'<?xml version="1.0" encoding="UTF-8"?>\r\n<response>\r\n<header>\r\n<resultCode>00</resultCode>\r\n<resultMsg>NORMAL SERVICE</resultMsg>\r\n</header>\r\n<body>\r\n<items>\r\n\r\n<item>\r\n\r\n<dataTime>2024-03-22 17:09</dataTime>\r\n<serialNo>ICW0W2100488</serialNo>\r\n<pm10>16</pm10>\r\n<pm25>5</pm25>\r\n<co2>439</co2>\r\n<vocs>236</vocs>\r\n<temp>24.5</temp>\r\n<humi>20</humi>\r\n<noise>71</noise>\r\n<cici>93</cici>\r\n</item>\r\n\r\n<item>\r\n\r\n<dataTime>2024-03-22 17:09</dataTime>\r\n<serialNo>ICW0W2100506</serialNo>\r\n<pm10>18</pm10>\r\n<pm25>5</pm25>\r\n<co2>52</co2>\r\n<vocs>15</vocs>\r\n<temp>18.1</temp>\r\n<humi>32</humi>\r\n<noise>54</noise>\r\n<cici>100</cici>\r\n</item>\r\n\r\n<item>\r\n\r\n<dataTime>2024-03-14 09:08</dataTime>\r\n<serialNo>ICW0W2100587</serialNo>\r\n<pm10>55</pm10>\r\n<pm25>20</pm25>\r\n<co2>392</co2>\r\n<vocs>6000</vocs>\r\n<temp>24.8</temp>\r\n<humi>23</humi>\r\n<noise>69</noise>\r\n<cici>62</cici>\r\n</item>\r\n\r\n<item>\r\n\r\n<dataTime>2024-03-22 17:09</dataTime>\r\n<serialNo>ICW0W2100582</serialNo>\r\n<pm10>22</pm10>\r\n<pm25>7</pm25>\r\n<co2>668</co2>\r\n<vocs>84</vocs>\r\n<temp>22.9</temp>\r\n<humi>28</humi>\r\n<noise>64</noise>\r\n<cici>95</cici>\r\n</item>\r\n\r\n<item>\r\n\r\n<dataTime>2024-03-22 17:09</dataTime>\r\n<serialNo>ICW0W2100579</serialNo>\r\n<pm10>6</pm10>\r\n<pm25>2</pm25>\r\n<co2>0</co2>\r\n<vocs>261</vocs>\r\n<temp>28.0</temp>\r\n<humi>17</humi>\r\n<noise>69</noise>\r\n<cici>89</cici>\r\n</item>\r\n\r\n<item>\r\n\r\n<dataTime>2024-03-22 17:10</dataTime>\r\n<serialNo>ICW0W2100562</serialNo>\r\n<pm10>13</pm10>\r\n<pm25>6</pm25>\r\n<co2>616</co2>\r\n<vocs>1256</vocs>\r\n<temp>24.9</temp>\r\n<humi>21</humi>\r\n<noise>70</noise>\r\n<cici>75</cici>\r\n</item>\r\n\r\n<item>\r\n\r\n<dataTime>2024-03-22 17:09</dataTime>\r\n<serialNo>ICW0W2100560</serialNo>\r\n<pm10>11</pm10>\r\n<pm25>3</pm25>\r\n<co2>533</co2>\r\n<vocs>6000</vocs>\r\n<temp>23.3</temp>\r\n<humi>25</humi>\r\n<noise>57</noise>\r\n<cici>68</cici>\r\n</item>\r\n\r\n<item>\r\n\r\n<dataTime>2024-03-22 17:09</dataTime>\r\n<serialNo>ICW0W2100549</serialNo>\r\n<pm10>16</pm10>\r\n<pm25>5</pm25>\r\n<co2>1378</co2>\r\n<vocs>441</vocs>\r\n<temp>19.5</temp>\r\n<humi>33</humi>\r\n<noise>66</noise>\r\n<cici>82</cici>\r\n</item>\r\n\r\n<item>\r\n\r\n<dataTime>2024-03-22 17:09</dataTime>\r\n<serialNo>ICW0W2100509</serialNo>\r\n<pm10>17</pm10>\r\n<pm25>5</pm25>\r\n<co2>347</co2>\r\n<vocs>6000</vocs>\r\n<temp>23.3</temp>\r\n<humi>30</humi>\r\n<noise>58</noise>\r\n<cici>69</cici>\r\n</item>\r\n\r\n<item>\r\n\r\n<dataTime>2024-03-19 17:57</dataTime>\r\n<serialNo>ICW0W2100499</serialNo>\r\n<pm10>33</pm10>\r\n<pm25>13</pm25>\r\n<co2>500</co2>\r\n<vocs>548</vocs>\r\n<temp>20.5</temp>\r\n<humi>30</humi>\r\n<noise>82</noise>\r\n<cici>86</cici>\r\n</item>\r\n\r\n<item>\r\n\r\n<dataTime>2024-03-19 13:26</dataTime>\r\n<serialNo>ICW0W2100498</serialNo>\r\n<pm10>36</pm10>\r\n<pm25>13</pm25>\r\n<co2>1781</co2>\r\n<vocs>645</vocs>\r\n<temp>24.5</temp>\r\n<humi>41</humi>\r\n<noise>86</noise>\r\n<cici>77</cici>\r\n</item>\r\n\r\n<item>\r\n\r\n<dataTime>2024-03-22 17:09</dataTime>\r\n<serialNo>ICW0W2100497</serialNo>\r\n<pm10>8</pm10>\r\n<pm25>2</pm25>\r\n<co2>658</co2>\r\n<vocs>30</vocs>\r\n<temp>25.7</temp>\r\n<humi>25</humi>\r\n<noise>62</noise>\r\n<cici>95</cici>\r\n</item>\r\n\r\n<item>\r\n\r\n<dataTime>2024-03-22 17:12</dataTime>\r\n<serialNo>ICW0W2100491</serialNo>\r\n<pm10>3</pm10>\r\n<pm25>1</pm25>\r\n<co2>919</co2>\r\n<vocs>20569</vocs>\r\n<temp>24.3</temp>\r\n<humi>26</humi>\r\n<noise>60</noise>\r\n<cici>56</cici>\r\n</item>\r\n\r\n<item>\r\n\r\n<dataTime>2024-03-22 17:09</dataTime>\r\n<serialNo>ICW0W2100485</serialNo>\r\n<pm10>17</pm10>\r\n<pm25>5</pm25>\r\n<co2>845</co2>\r\n<vocs>0</vocs>\r\n<temp>23.6</temp>\r\n<humi>32</humi>\r\n<noise>79</noise>\r\n<cici>96</cici>\r\n</item>\r\n\r\n<item>\r\n\r\n<dataTime>2024-03-22 17:09</dataTime>\r\n<serialNo>ICW0W2100481</serialNo>\r\n<pm10>7</pm10>\r\n<pm25>2</pm25>\r\n<co2>1786</co2>\r\n<voc ...

# %%
# import library

import requests, xmltodict, json

import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

# %%
dict_res = xmltodict.parse(response.content)

json_string = json.dumps(dict_res['response']['body']['items'], ensure_ascii=False)

jsonObj = json.loads(json_string)

df = pd.DataFrame(jsonObj['item'])

df.columns = ['데이터 시간','시리얼번호','미세먼지 (㎍/㎥)','초미세먼지 (㎍/㎥)', '이산화탄소 (ppm)','휘발성유기화합물 (ppb)','온도(℃)','습도(%)','소음(dB)','통합실내지수']

df
# Out:
#               데이터 시간         시리얼번호 미세먼지 (㎍/㎥) 초미세먼지 (㎍/㎥) 이산화탄소 (ppm)  \
# 0   2024-03-22 17:09  ICW0W2100488         16           5         439
# 1   2024-03-22 17:09  ICW0W2100506         18           5          52
# 2   2024-03-14 09:08  ICW0W2100587         55          20         392
# 3   2024-03-22 17:09  ICW0W2100582         22           7         668
# 4   2024-03-22 17:09  ICW0W2100579          6           2           0
# ..               ...           ...        ...         ...         ...
# 82  2024-03-14 09:08  ICW0W2100587         55          20         392
# 83  2024-03-22 17:08  ICW0W2100582         24           7         675
# 84  2024-03-22 17:08  ICW0W2100579          6           2           0
# 85  2024-03-22 17:09  ICW0W2100562         14           6         618
# 86  2024-03-22 17:08  ICW0W2100560         13           4         536
#
#    휘발성유기화합물 (ppb) 온도(℃) 습도(%) 소음(dB) 통합실내지수
# 0             236  24.5    20     71     93
# 1              15  18.1    32     54    100
# 2            6000  24.8    23     69     62
# 3              84  22.9    28     64     95
# 4             261  28.0    17     69     89
# ..            ...   ...   ...    ...    ...
# 82           6000  24.8    23     69     62
# 83             88  22.9    28     63     95
# 84            251  28.0    17     61     89
# 85           1269  24.9    21     75     75
# 86           6000  23.3    25     57     68
#
# [87 rows x 10 columns]

# %%
# 데이터 파일 새로 생성 (새로 생성!!!!)
df.to_csv('TeamAPI.csv', index=False, encoding='euc-kr')

# %%
# 저장된 파일에 데이터 추가 이어쓰기 (처음 이후엔 이거 실행)
df.to_csv('TeamAPI.csv', mode='a', index=False, encoding='euc-kr')
